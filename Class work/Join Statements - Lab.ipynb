# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of `JOIN` statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
#
# * Write SQL queries that make use of various types of joins
# * Compare and contrast the various types of joins
# * Discuss how primary and foreign keys are used in SQL
# * Decide and perform whichever type of join is best for retrieving desired data

# %% [markdown]
# ## CRM ERD
#
# In this lab, you'll use the same customer relationship management (CRM) database that you saw from the previous lesson.
# <img src='https://curriculum-content.s3.amazonaws.com/data-science/images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database `'data.sqlite'`.

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite')

# %% [markdown]
# ## Select the names of all employees in Boston
#
# Hint: join the employees and offices tables. Select the first and last name.

# %%
q = ''' 
SELECT 
    firstName,lastName
FROM employees
JOIN offices
    USING (officeCode)
WHERE city="Boston"
'''
pd.read_sql(q,conn)
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Are there any offices that have zero employees?
# Hint: Combine the employees and offices tables and use a group by. Select the office code, city, and number of employees.

# %%
q = ''' 
SELECT officeCode,city ,COUNT(e.employeeNumber) AS n_employee
FROM employees e
JOIN offices o
    USING (officeCode)
GROUP BY officeCode
HAVING n_employee = 0
'''
pd.read_sql(q,conn)
# Out:
# Empty DataFrame
# Columns: [officeCode, city, n_employee]
# Index: []

# %% [markdown]
# ## Write 3 questions of your own and answer them

# %%
# Answers will vary

# Example question: 
"""
How many customers are there per office?
"""
q = ''' 
SELECT count(c.customerNumber) as n_customers,*
FROM customers c
JOIN offices o
    USING (state)
GROUP BY officecode
'''
pd.read_sql(q,conn)
# Out:
#    n_customers customerNumber                  customerName contactLastName  \
# 0           11            124  Mini Gifts Distributors Ltd.          Nelson
# 1            9            173    Cambridge Collectables Co.           Tseng
# 2            6            131             Land of Toys Inc.             Lee
# 3           73            103             Atelier graphique         Schmitt
# 4           73            103             Atelier graphique         Schmitt
# 5           73            103             Atelier graphique         Schmitt
#
#   contactFirstName       phone             addressLine1 addressLine2  \
# 0            Susan  4155551450          5677 Strong St.
# 1            Jerry  6175555555           4658 Baden Av.
# 2             Kwai  2125557818  897 Long Airport Avenue
# 3          Carine   40.32.2555           54, rue Royale
# 4          Carine   40.32.2555           54, rue Royale
# 5          Carine   40.32.2555           54, rue Royale
#
# ...

# %%
q = ''' 
SELECT officeCode,o.city ,COUNT(c.customerNumber) AS c_employee
FROM employees e
JOIN offices o
    USING (officeCode)
JOIN customers c
    ON e.employeeNumber = c.salesRepEmployeeNumber
GROUP BY officeCode
'''
pd.read_sql(q,conn)
# Out:
#   officeCode           city  c_employee
# 0          1  San Francisco          12
# 1          2         Boston          12
# 2          3            NYC          15
# 3          4          Paris          29
# 4          5          Tokyo           5
# 5          6         Sydney          10
# 6          7         London          17

# %%
"""
Question 2
"""

# Your code here

# %%
"""
Question 3
"""

# Your code here

# %% [markdown]
# ## Level Up 1: Display the names of every individual product that each employee has sold
#
# Hint: You will need to use multiple `JOIN` clauses to connect all the way from employee names to product names.

# %%
q = '''
SELECT firstName,lastName,productName
FROM Products p
JOIN orderdetails
    USING (productcode)
JOIN orders
    USING(orderNumber)
JOIN customers c
    USING(customerNumber)
JOIN employees e
    On e.employeenumber = c.salesRepEmployeeNumber
'''
pd.read_sql(q,conn)
# Out:
#      firstName   lastName                            productName
# 0       George     Vanauf  1969 Harley Davidson Ultimate Chopper
# 1         Loui     Bondur  1969 Harley Davidson Ultimate Chopper
# 2         Loui     Bondur  1969 Harley Davidson Ultimate Chopper
# 3       Leslie   Thompson  1969 Harley Davidson Ultimate Chopper
# 4       Leslie   Jennings  1969 Harley Davidson Ultimate Chopper
# ...        ...        ...                                    ...
# 2991     Peter      Marsh                             Pont Yacht
# 2992     Larry       Bott                             Pont Yacht
# 2993    Gerard  Hernandez                             Pont Yacht
# 2994    Gerard  Hernandez                             Pont Yacht
# 2995     Steve  Patterson                             Pont Yacht
#
# [2996 rows x 3 columns]

# %% [markdown]
# ## Level Up 2: Display the number of products each employee has sold
#
# Alphabetize the results by employee last name.
#
# Hint: Use the `quantityOrdered` column from `orderDetails`. Also, think about how to group the data when some employees might have the same first or last name.

# %%
q = '''
SELECT firstName,lastName,productName,SUM(quantityordered) as n_products
FROM Products p
JOIN orderdetails
    USING (productcode)
JOIN orders
    USING(orderNumber)
JOIN customers c
    USING(customerNumber)
JOIN employees e
    On e.employeenumber = c.salesRepEmployeeNumber
GROUP BY employeenumber
ORDER BY lastName
'''
pd.read_sql(q,conn)
# Out:
#    firstName   lastName                            productName  n_products
# 0       Loui     Bondur  1969 Harley Davidson Ultimate Chopper        6186
# 1      Larry       Bott  1969 Harley Davidson Ultimate Chopper        8205
# 2     Pamela   Castillo  1969 Harley Davidson Ultimate Chopper        9290
# 3      Julie   Firrelli               1952 Alpine Renault 1300        4227
# 4       Andy     Fixter  1969 Harley Davidson Ultimate Chopper        6246
# 5     Martin     Gerard               1952 Alpine Renault 1300        4180
# 6     Gerard  Hernandez  1969 Harley Davidson Ultimate Chopper       14231
# 7     Leslie   Jennings  1969 Harley Davidson Ultimate Chopper       11854
# 8      Barry      Jones  1969 Harley Davidson Ultimate Chopper        7486
# 9      Peter      Marsh  1969 Harley Davidson Ultimate Chopper        6632
# 10      Mami      Nishi               1952 Alpine Renault 1300        4923
# ...

# %% [markdown]
# ## Level Up 3: Display the names employees who have sold more than 200 different products
#
# Hint: this is different from the previous question because the quantity sold doesn't matter, only the number of different products

# %%
q = '''
SELECT firstName,lastName,productName,COUNT(ProductCode) as n_products
FROM Products p
JOIN orderdetails
    USING (productcode)
JOIN orders
    USING(orderNumber)
JOIN customers c
    USING(customerNumber)
JOIN employees e
    On e.employeenumber = c.salesRepEmployeeNumber
GROUP BY employeenumber
HAVING n_products>200
ORDER BY lastName
'''
pd.read_sql(q,conn)
# Out:
#   firstName   lastName                            productName  n_products
# 0     Larry       Bott  1969 Harley Davidson Ultimate Chopper         236
# 1    Pamela   Castillo  1969 Harley Davidson Ultimate Chopper         272
# 2    Gerard  Hernandez  1969 Harley Davidson Ultimate Chopper         396
# 3    Leslie   Jennings  1969 Harley Davidson Ultimate Chopper         331
# 4     Barry      Jones  1969 Harley Davidson Ultimate Chopper         220
# 5    George     Vanauf  1969 Harley Davidson Ultimate Chopper         211

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You practiced using join statements and leveraged your foreign keys knowledge!
