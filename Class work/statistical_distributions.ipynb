# %% [markdown]
# #### Measures of Central Tendency and Measures of Dispersion

# %% [markdown]
# Measures of Central Tendency:
#
# * Mean: Average value of the dataset.
# * Median: The middle value when the dataset is sorted.
# * Mode: The most frequently occurring value in the dataset.

# %% [markdown]
# Measures of Dispersion:
#
# * Variance: Measures how far each number in the dataset is from the mean.
#
# * Standard Deviation: The square root of variance, representing the average distance of each data point from the mean.

# %%
# Find mean of the scores
list_scores = [80, 90, 100, 50, 40, 100]
list_scores.mean()

mean_values = list_scores.sum()/6

# Median value
list_scores.sorted().median()

# Mode
list_scores.mode()

# %%
# Import necessary packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Generate a sample dataset
# Data type: Continuous
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=170, scale=10, size=1000) # mean = 170, std deviation = 10
data.min()
# Out:
# 137.58732659930928

# %%
data.max()
# Out:
# 208.52731490654722

# %%
mean_value = np.mean(data)
mean_value
# Out:
# 170.19332055822326

# %%
# import numpy as np
median_value = np.median(data)
median_value
# Out:
# 170.2530061223489

# %%
variance_value = np.var(data)
print(f"The variance of the data provided is:", variance_value)
# Out:
# The variance of the data provided is: 95.79049897315173

# %%
standard_deviation = np.std(data)
standard_deviation
# Out:
# 9.787262077473542

# %%
a = 170.19 - 9.78

a = mean_value - standard_deviation

b = mean_value + standard_deviation

a, b
# Out:
# (160.40605848074972, 179.9805826356968)

# %%
# help(np)

# %%
# Measures of Central Tendency
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data).mode  # Directly retrieve the mode value

# Measures of Dispersion
variance = np.var(data)
std_deviation = np.std(data)

# Print the results
print("Measures of Central Tendency:")
print(f"Mean: {mean:.2f}")
print(f"Median: {median:.2f}")
print(f"Mode: {mode:.2f}")

print("\nMeasures of Dispersion:")
print(f"Variance: {variance:.2f}")
print(f"Standard Deviation: {std_deviation:.2f}")

# Visualization of the Normal Distribution
plt.figure(figsize=(12, 4))
sns.histplot(data, bins=30, kde=True, stat='density', color='skyblue', label='Data Histogram')
plt.axvline(mean, color='red', linestyle='--', label='Mean')
plt.axvline(median, color='green', linestyle='--', label='Median')
plt.axvline(mode, color='purple', linestyle='--', label='Mode');

# Formatting the plot
plt.title('Normal Distribution with Central Tendency Measures')
plt.xlabel('Height (cm)')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# Measures of Central Tendency:
# Mean: 170.19
# Median: 170.25
# Mode: 137.59
#
# Measures of Dispersion:
# Variance: 95.79
# Standard Deviation: 9.79

# %% [markdown]
# Visualization:
#
# * A histogram is plotted with a kernel density estimate (KDE) overlay to visualize the normal distribution of the data.
#
# * Vertical lines represent the mean, median, and mode to illustrate their positions in the distribution.

# %% [markdown]
# Output Explanation:
#
# > Standard Deviation
# If you consider the average height of 170 cm:
#
# * Most individuals in your dataset will likely have heights within one standard deviation (±9.79 cm) of the mean, which would be approximately between 160.21 cm and 179.79 cm.
#
# > Variance
#
# * A variance of 95.79 indicates that the data points (heights in this case) deviate from the mean (170 cm) by an average of about 95.79 square centimeters. Since variance is expressed in squared units, it can be a bit abstract for interpretation.

# %% [markdown]
# # Statistical Distributions and Their Use Cases
#
# ## Introduction
#
# As a data scientist, you'll often have to work with statistical distributions.  This includes selecting which distribution is most representative of a given set of data. A typical use case includes A/B testing, where understanding the process that generated the data is important. You can think of distributions in relation to statistical analysis as to data structures to computer programming.
#
# There are an enormous amount of distributions out there, but you'll see about a handful of distributions that can represent the vast majority of situations you'll come across. In the upcoming series of lessons, you'll look at ways to analyze common distributions you will encounter most frequently.
#
# ## Objectives
#
# You will be able to:
#
# * Define statistical distributions
# * Differentiate between discrete and continuous distributions
# * List the common distributions and their use cases
#
# ## What is a Statistical Distribution?
#
# A statistical distribution is a **representation of the frequencies of potential events** or the percentage of time each event occurs. Here we will focus on a particular kind of statistical distribution: a **probability distribution**.
#
# Returning to set theory, a probability distribution mathematically represents the probabilities of sets of variables $X$ and sets of events $E$ such that $X \in E$ ($X$ is a member of $E$), fully written as $P(X \in E)$. So, for a given $x$ value and a given event, a probability distribution gives you the probability that $x$ belongs to that event.
#
# Because they mathematically represent probabilities of events, rules applying to probabilities in general also apply to probability distributions:
#
# ### 1. $P(X \in E) \in \mathbb{R}, P(X \in E) \geq 0$
# - The probability that a certain $X$ belongs to a certain $E$ is a non-negative real number
# - This corresponds to the **positivity** axiom from probability theory
#
# ### 2. $P(X \in E) \leq 1, P(\Omega) = 1$
# - The probability that a certain $X$ belongs to a certain $E$ is less than or equal to 1, and the probability of some event within the sample space occurring is 1
# - This corresponds to the **unitarity** axiom (probability of a certain event)
#
# ### 3. $P(X \in \underset{i}{\bigsqcup} E_i) = \underset{i}{\Sigma}P(X \in E_i)$ for any disjoint family of sets $\{E_i\}$
# - The probability that a certain $X$ belongs to the union of these disjoint (mutually exclusive) events is equal to the sum of the probability that $X$ belongs to each event, added together
# - This corresponds to the **additivity** axiom (for mutually exclusive events). ***In a probability distribution, all events must be must be mutually exclusive.***
#
# This may feel pretty vague and theoretical, which is why we'll use two examples to clarify this concept.
#
# ## Initial Probability Distribution Examples
#
# We'll start with one example of a discrete distribution, and one example of a continuous distribution.

# %% [markdown]
# ### Rolling Dice Distribution
#
# Let's think back about our example of rolling dice. You know that when rolling a single die, you will obtain a number between 1 and 6, with each outcome to be as likely, as denoted in this table:
#
# | outcome     | 1   | 2   | 3   | 4   | 5   | 6   |
# |-------------|-----|-----|-----|-----|-----|-----|
# | probability | 1/6 | 1/6 | 1/6 | 1/6 | 1/6 | 1/6 |
#
#
# You can also represent this graphically as follows:
#
# <img src="https://curriculum-content.s3.amazonaws.com/data-science/images/dice_roll_pmf.png" width="350">
#
# Note how, with a fair die, the chance of throwing each number is _exactly_ 1/6 (or 0.1666). The number of outcomes is finite and the outcome is a set of values. In this case, you are dealing with a **discrete distribution**.

# %% [markdown]
# ### Temperature Distribution
#
# Let's look at another situation. Imagine we want to think of the distribution of the temperature in New York on June 1st. Thinking about this, you could say that the temperature would generally range between 65 and 95 degrees Fahrenheit (more extreme values would be exceptional), with the average around 80 degrees.
#
# A potential distribution looks like this:
#
# <img src="https://curriculum-content.s3.amazonaws.com/data-science/images/weather_pdf.png" width="400">
#
# Note that instead of bars, which we had for the dice example, we have _continuous_ lines here. Our distribution is a **continuous distribution** because temperature is a continuous value (we can have a temperature of 80 degrees, of 80.5 degrees, of 80.0034 degrees, etc.).

# %%
# Categorical data (Discrete i.e 0,1 Ordinal) and Numerical data
# Independent and Dependent Variable
# Linear Regression
# Dependent variable is y (Outcome/Target variable)
# Data type for y which is dependent variable should be numerical (continous, float) i.e height (65.5), temperature(-3.333, 24.67)

# Logistic regression

y = mx + c

# %% [markdown]
# ## Common Distributions
#
# In this image, you can see the general shapes of some common distributions. The horizontal axis in each chart represents the set of possible numeric outcomes. The vertical axis describes the probability of the respective outcomes.
#
# ![](https://curriculum-content.s3.amazonaws.com/data-science/images/dists.png)
#
# You'll get a more in-depth overview of some important distributions in the next few lessons, but to give you an initial idea of some applications, we'll give you a quick overview below.
# Let's quickly talk about some common distributions and their use cases below.
#
# ## Discrete vs Continuous Distributions
#
# When dealing with **discrete** data you use a **Probability Mass Function (PMF)** (as in our dice example). When dealing with **continuous** data, you use a **Probability Density Function (PDF)** (see our temperature example).
#
# Based on the variation of their attributes, data distributions can take many shapes and forms. In the next few lessons, you'll learn how to describe data distributions. Very often, distributions are described using their statistical mean (or **expected value**) and variance of the data, but this is not always the case. You'll see more on this in the next few lessons.
#
# ### Examples of Discrete Distributions
#
# #### The Bernoulli Distribution
#
# The Bernoulli distribution represents the probability of success for a certain experiment (the outcome being "success or not", so there are two possible outcomes). A coin toss is a classic example of a Bernoulli experiment with a probability of success 0.5 or 50%, but a Bernoulli experiment can have any probability of success between 0 and 1.
#
# #### The Poisson Distribution
#
# The Poisson distribution represents the probability of $n$ events in a given time period when the overall rate of occurrence is constant. A typical example is pieces of mail. If your overall mail received is constant, the number of items received on a single day (or month) follows a Poisson distribution. Other examples might include visitors to a website, or customers arriving at a store, or clients waiting to be served in a queue.
#
# #### The Uniform Distribution
#
# The uniform distribution occurs when all possible outcomes are equally likely. The dice example shown before follows a uniform distribution with equal probabilities for throwing values from 1 to 6. The dice example follows a discrete uniform distribution, but continuous uniform distributions exist as well.
#
# ### Examples of Continuous Distributions
#
# #### The Normal or Gaussian Distribution
#
# A normal distribution is the single most important distribution; you'll come across it very often. The normal distribution follows a bell shape and is a foundational distribution for many models and theories in statistics and data science. A normal distribution turns up very often when dealing with real-world data including heights, weights of different people, errors in some measurement or grades on a test. Our temperature example above follows a normal distribution as well!
#
# ## Summary
#
# In this lesson, you learned about the concept of (discrete and continuous) probability distributions, as well as some common ones. You'll learn more about distributions and their properties in the next few lessons!

# %% [markdown]
# ### Normal Distribution

# %% [markdown]
# Continuous data. Heights of people, test scores

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, sigma = 170, 10
x = np.linspace(140, 200, 100)
pdf = (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / sigma) ** 2)
plt.plot(x, pdf)
plt.title('Normal Distribution')
plt.xlabel('Height (cm)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Binomal Distribution

# %% [markdown]
# Discrete outcomes; success/failure. Flipping a coin, quality control

# %%
from scipy.stats import binom
n, p = 10, 0.5
x = range(n+1)
pmf = binom.pmf(x, n, p)
plt.bar(x, pmf)
plt.title('Binomial Distribution')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# ### Poisson Distribution

# %% [markdown]
# Count of events in fixed interval. Number of emails received per hour

# %%
from scipy.stats import poisson
mu = 5
x = range(0, 15)
pmf = poisson.pmf(x, mu)
plt.bar(x, pmf)
plt.title('Poisson Distribution')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# ### Exponential Distribution

# %% [markdown]
# Time until an event occurs.

# %%
from scipy.stats import expon
scale = 2
x = np.linspace(0, 15, 100)
pdf = expon.pdf(x, scale=scale)
plt.plot(x, pdf)
plt.title('Exponential Distribution')
plt.xlabel('Time')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Uniform Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
a, b = 1, 6
x = np.linspace(a, b, 100)
pdf = np.ones_like(x) / (b - a)
plt.plot(x, pdf)
plt.title('Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Geometric Distribution

# %%
from scipy.stats import geom
p = 0.5
x = range(1, 11)
pmf = geom.pmf(x, p)
plt.bar(x, pmf)
plt.title('Geometric Distribution')
plt.xlabel('Trials')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# ### Beta Distribution

# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
a, b = 2, 5
x = np.linspace(0, 1, 100)
pdf = beta.pdf(x, a, b)
plt.plot(x, pdf)
plt.title('Beta Distribution')
plt.xlabel('Probability')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Gamma Distribution

# %%
from scipy.stats import gamma
import matplotlib.pyplot as plt

shape, scale = 2, 2
x = np.linspace(0, 20, 100)
pdf = gamma.pdf(x, shape, scale=scale)
plt.plot(x, pdf)
plt.title('Gamma Distribution')
plt.xlabel('Time')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### Probability Mass Function (PMF) and Probability Density Function (PDF)

# %% [markdown]
# The probability mass function (PMF) and the probability density function (PDF) are both used to describe the probabilities of random variables, but they apply to different types of variables.
#
# * Probability Mass Function (PMF)
#
# Definition:
#
# The PMF is used for discrete random variables. It gives the probability that a discrete random variable is exactly equal to some value.
# Formula: For a discrete random variable
# 𝑋
# X, the PMF is denoted as
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x).
#
# Characteristics:
#
# The sum of all probabilities for all possible values must equal 1:
# ∑
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# ∑P(X=x)=1.
# It can take values from a countable set (e.g., integers).
# When to use: Use PMF when dealing with discrete random variables, like the number of heads in a series of coin tosses or the roll of a die.
#
# * Probability Density Function (PDF)
#
# Definition:
#
# The PDF is used for continuous random variables. It describes the relative likelihood of a random variable taking on a particular value, but it does not provide probabilities for exact values (since the probability of any single point in a continuous distribution is zero).
#
# Formula:
#
# For a continuous random variable
# 𝑌
# Y, the PDF is denoted as
# 𝑓
# 𝑌
# (
# 𝑦
# )
# f
# Y
# ​
#  (y), where the probability that
# 𝑌
# Y falls within a range
# 𝑎
# a to
# 𝑏
# b is given by the integral of the PDF over that range:
# 𝑃
# (
# 𝑎
# ≤
# 𝑌
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# 𝑌
# (
# 𝑦
# )
#
# 𝑑
# 𝑦
# P(a≤Y≤b)=∫
# a
# b
# ​
#  f
# Y
# ​
#  (y)dy.
#
# Characteristics:
#
# The area under the PDF over the entire range must equal 1:
# ∫
# −
# ∞
# ∞
# 𝑓
# 𝑌
# (
# 𝑦
# )
#
# 𝑑
# 𝑦
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f
# Y
# ​
#  (y)dy=1.
# It can take values greater than 1, but the area under the curve must be 1.
# When to use: Use PDF when dealing with continuous random variables, such as the height of people or the time taken to complete a task.
#
# Summary:
#
# Use PMF for discrete variables (countable outcomes).
# Use PDF for continuous variables (uncountable outcomes, measured over an interval).

# %% [markdown]
# **Real-Life Example: PMF and PDF in Python**
#
# Let's consider a real-life example using car accidents to demonstrate both PMF and PDF:
#
# * PMF Example: Number of car accidents at a specific intersection in a day (a discrete random variable).
#
# * PDF Example: The time taken for a car to travel a specific distance (a continuous random variable).

# %% [markdown]
# ### a. Probability Mass Function Example: Number of car accidents at a specific intersection in a day (a discrete random variable).

# %% [markdown]
# Use PMF when:
#
# * You are dealing with discrete outcomes.
# * You want to find the exact probabilities of specific counts or events.
# * Example: "What is the probability that there are exactly 3 car accidents at this intersection today?"

# %% [markdown]
# 1. Probability Mass Function (PMF)
# Mathematical Formula
# For a discrete random variable
# 𝑋
# X (in this case, the number of car accidents), the PMF is defined as:
#
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# P(X=x)=p
# x
# ​
#
# where
# 𝑝
# 𝑥
# p
# x
# ​
#   is the probability of
# 𝑋
# X taking the value
# 𝑥
# x.
#
# Explanation
# In our car accidents example:
#
# Let
# 𝑋
# X be the random variable representing the number of car accidents that occur at a specific intersection in one day.
# The PMF,
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x), gives the probability that exactly
# 𝑥
# x accidents occur on a given day.
#
# For example, if we calculate the PMF and find:
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 0.25
#
# * P(X=0)=0.25 (there’s a 25% chance of no accidents),
#
#
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 0.40
#
# * P(X=1)=0.40 (there’s a 40% chance of one accident),
#
# 𝑃
# (
# 𝑋
# =
# 2
# )
# =
# 0.20
#
# * P(X=2)=0.20 (there’s a 20% chance of two accidents), etc.
#
# This allows us to understand the likelihood of various outcomes at the intersection.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset (replace with actual data path)
data = pd.read_csv('car_accidents.csv')  # Assume it contains a 'num_accidents' column

# Count occurrences of each number of accidents
accident_counts = data['num_accidents'].value_counts().sort_index()

# Calculate PMF
pmf = accident_counts / accident_counts.sum()

# Plot PMF
plt.bar(pmf.index, pmf.values)
plt.xlabel('Number of Accidents')
plt.ylabel('Probability')
plt.title('Probability Mass Function of Car Accidents')
plt.show()

# %% [markdown]
# ### Probability Density Function (PDF) Example: The time taken for a car to travel a specific distance (a continuous random variable).

# %% [markdown]
# Use PDF when:
#
# * You are dealing with continuous outcomes.
# * You want to find the probability of a range of values rather than specific outcomes.
# * Example: "What is the probability that a car takes between 15 and 30 minutes to travel to a destination?"

# %% [markdown]
# 2. Probability Density Function (PDF)
# Mathematical Formula
# For a continuous random variable
# 𝑌
# Y (in this case, the travel time), the PDF is defined such that:
#
# 𝑓
# 𝑌
# (
# 𝑦
# )
# =
# lim
# ⁡
# Δ
# 𝑦
# →
# 0
# 𝑃
# (
# 𝑦
# ≤
# 𝑌
# ≤
# 𝑦
# +
# Δ
# 𝑦
# )
# Δ
# 𝑦
# f
# Y
# ​
#  (y)=
# Δy→0
# lim
# ​
#
# Δy
# P(y≤Y≤y+Δy)
# ​
#
# where
# 𝑓
# 𝑌
# (
# 𝑦
# )
# f
# Y
# ​
#  (y) is the density function at point
# 𝑦
# y.
#
# Explanation
# In our travel time example:
#
# Let
# 𝑌
# Y be the random variable representing the time (in minutes) taken for a car to travel to a destination.
# The PDF,
# 𝑓
# 𝑌
# (
# 𝑦
# )
# f
# Y
# ​
#  (y), indicates the density of probability at each travel time
# 𝑦
# y. However, it does not give the probability of exactly
# 𝑦
# y; instead, we use it to find probabilities over an interval.
# For example, to find the probability that travel time is between 15 and 30 minutes, we calculate:
#
# 𝑃
# (
# 15
# ≤
# 𝑌
# ≤
# 30
# )
# =
# ∫
# 15
# 30
# 𝑓
# 𝑌
# (
# 𝑦
# )
#
# 𝑑
# 𝑦
# P(15≤Y≤30)=∫
# 15
# 30
# ​
#  f
# Y
# ​
#  (y)dy
# This integral represents the area under the PDF curve between 15 and 30 minutes, giving us the probability that a car takes that amount of time to travel.

# %%
import seaborn as sns

# Load travel time data (replace with actual data path)
travel_data = pd.read_csv('travel_times.csv')  # Assume it contains a 'travel_time' column

# Plot PDF using Seaborn
sns.kdeplot(travel_data['travel_time'], fill=True)
plt.xlabel('Travel Time (minutes)')
plt.ylabel('Density')
plt.title('Probability Density Function of Travel Times')
plt.show()
